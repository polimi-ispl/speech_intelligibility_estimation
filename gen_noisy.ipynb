# %%
import os
import librosa 
import librosa.core
import librosa.util
import numpy as np
import scipy as sp
import scipy.io
import soundfile as sf
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Retrieve path to files

# %%
noise_path = "dataset/noise/"
orig_path = "dataset/orig/"
maindir_path = "dataset/speech/"
trans_path = "dataset/trans"

# here eventually we will inside a pandas dataframe of the original Libri
noise_files = [f for f in os.listdir(noise_path)]
clean_files = [f for f in os.listdir(orig_path)]

# %% [markdown]
# ### Create a dataframe for storing dataset information

# %%
col = ['orig_name', 'orig_path', 'name', 'path', 'noise_type', 'SNR', 'talker', 'book','orig_transcription', 'orig_transcription_path']
db_info = pd.DataFrame(columns=col)

# %% [markdown]
# ### Some parameters

# %%
## Parameters (eventually fix and remove constraint)

## noise files are wav 16 at 48000
nbit = 16
SNR = [0,5,10,15]

# %% [markdown]
# ### Organization of the folder dataset
# 1. speech : noisy files
#     * file directory: one folder for each file of the LibriSpeech dataset; *example dir name*: <b>84-121550-0000</b>
#         - noise type: one folder for each type of noise; *example dir name*: <b>train</b> <br>
#           here noisy speech files with different SNRs; *example file path*: <b>84-121550-0000/train/84-121550-0000_train_5.wav</b>
#
# 2. noise : noise files
# 3. orig : original files
# 4. trans : original transcriptions

# %% [markdown]
# ### Add noise to clean files
# Maybe we can avoid to have 3 nested for cycles?<br>
# Probably can be useful to have a pipeline made of blocks

# %%
# here in future we should read from a pandas dataframe having the paths for all the files we use from LibriSpeech
for f in clean_files:
    
    origfile_path = os.path.join(orig_path, f)
    
    clean, orig_samplerate = sf.read(origfile_path)
    clean = np.array(clean)
    
    origfile_name = f.replace('.flac','')
    dir_path = os.path.join(maindir_path,origfile_name)
    if not os.path.isdir(dir_path):
        os.mkdir(dir_path)
    
    talker = f.split('-')[0]
    book = f.split('-')[1]
    
    # retrieve transcription
    transfile_name = f.split('-')[:2]
    transfile_name = '-'.join(transfile_name)+'.trans.txt'
    
    
    with open(os.path.join(trans_path,transfile_name)) as f:
        content = f.readlines()
    
    for row in content:
        splitted = row.split(' ')
        if splitted[0] == origfile_name:
            transcription = ' '.join(splitted[1:])
            break
    
    # real noises
    for n in noise_files:
        noise_name = n.replace('.wav','')
        subdir_path = os.path.join(dir_path,noise_name)
        if not os.path.isdir(subdir_path):
            os.mkdir(subdir_path)
        
        noise_samplerate, noise = scipy.io.wavfile.read(os.path.join(noise_path, n))
        noise = np.float32(noise)/ np.float32(2**(nbit-1))

        if(orig_samplerate > noise_samplerate):
            clean = librosa.resample(clean, orig_samplerate, noise_samplerate)
            samplerate = noise_samplerate
        else:
            noise = librosa.resample(noise, noise_samplerate, orig_samplerate)
            samplerate = orig_samplerate
            
        if (noise.shape[0] > clean.shape[0]):
            noise = noise[:clean.shape[0]]
        
        
        norm_factor = np.sqrt(np.mean(np.abs(clean)**2)/np.mean(np.abs(noise)**2))
        noise = noise*norm_factor
        
        for s in SNR:
            noise_gain = 1/(10**(s/20))
            noise_scaled = noise*noise_gain
            noisy = clean + noise_scaled
            file_name = origfile_name +'_'+ noise_name+'_'+str(s)
            file_path = os.path.join(subdir_path, file_name)+'.wav'
            sp.io.wavfile.write(file_path, samplerate, noisy)
            file_info = pd.Series([origfile_name, origfile_path, file_name, file_path, noise_name, s, talker,book, transcription,os.path.join(trans_path, transfile_name)], index=col)
            db_info = db_info.append(file_info, ignore_index = True)
      
    # white noise
    white_noise = np.random.normal(size=clean.shape)
    white_norm_factor = np.sqrt(np.mean(np.abs(clean)**2)/np.mean(np.abs(white_noise)**2))
    white_noise = white_noise*norm_factor
    white_subdir_path = os.path.join(dir_path, 'white')
    if not os.path.isdir(white_subdir_path):
        os.mkdir(white_subdir_path)
    
    for s in SNR:
        white_gain = 1/(10**(s/20))
        white_scaled = white_noise*white_gain
        noisy = clean + white_scaled
        file_name = origfile_name +'_white_'+str(s)
        file_path = os.path.join(white_subdir_path, file_name)+'.wav'
        sp.io.wavfile.write(file_path, samplerate, noisy)
        file_info = pd.Series([origfile_name, origfile_path, file_name, file_path, 'white', s, talker,book, transcription,os.path.join(trans_path, transfile_name)], index=col)
        db_info = db_info.append(file_info, ignore_index = True)

# %%
white_noise = np.random.normal(size=clean.shape)

ipd.Audio(white_noise, rate=samplerate) # load a local WAV file
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython.display as ipd
ipd.Audio(noisy, rate=samplerate) # load a local WAV file
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
noise_samplerate, noise = scipy.io.wavfile.read(os.path.join(noise_path, n))
# Out:
#           orig_name                         orig_path  \
# 0    84-121550-0000  dataset/orig/84-121550-0000.flac
# 1    84-121550-0000  dataset/orig/84-121550-0000.flac
# 2    84-121550-0000  dataset/orig/84-121550-0000.flac
# 3    84-121550-0000  dataset/orig/84-121550-0000.flac
# 4    84-121550-0000  dataset/orig/84-121550-0000.flac
# 5    84-121550-0000  dataset/orig/84-121550-0000.flac
# 6    84-121550-0000  dataset/orig/84-121550-0000.flac
# 7    84-121550-0000  dataset/orig/84-121550-0000.flac
# 8    84-121550-0000  dataset/orig/84-121550-0000.flac
# 9    84-121550-0000  dataset/orig/84-121550-0000.flac
# 10   84-121550-0000  dataset/orig/84-121550-0000.flac
# 11   84-121550-0000  dataset/orig/84-121550-0000.flac
# 12   84-121550-0000  dataset/orig/84-121550-0000.flac
# 13   84-121550-0000  dataset/orig/84-121550-0000.flac
# 14   84-121550-0000  dataset/orig/84-121550-0000.flac
# 15   84-121550-0000  dataset/orig/84-121550-0000.flac
# 16   84-121550-0001  dataset/orig/84-121550-0001.flac
# 17   84-121550-0001  dataset/orig/84-121550-0001.flac
# 18   84-121550-0001  dataset/orig/84-121550-0001.flac
# 19   84-121550-0001  dataset/orig/84-121550-0001.flac
# 20   84-121550-0001  dataset/orig/84-121550-0001.flac
# 21   84-121550-0001  dataset/orig/84-121550-0001.flac
# 22   84-121550-0001  dataset/orig/84-121550-0001.flac
# 23   84-121550-0001  dataset/orig/84-121550-0001.flac
# 24   84-121550-0001  dataset/orig/84-121550-0001.flac
# 25   84-121550-0001  dataset/orig/84-121550-0001.flac
# 26   84-121550-0001  dataset/orig/84-121550-0001.flac
# 27   84-121550-0001  dataset/orig/84-121550-0001.flac
# 28   84-121550-0002  dataset/orig/84-121550-0002.flac
# 29   84-121550-0002  dataset/orig/84-121550-0002.flac
# ..              ...                               ...
# 282  84-121550-0009  dataset/orig/84-121550-0009.flac
# 283  84-121550-0009  dataset/orig/84-121550-0009.flac
# 284  84-121550-0009  dataset/orig/84-121550-0009.flac
# 285  84-121550-0009  dataset/orig/84-121550-0009.flac
# 286  84-121550-0009  dataset/orig/84-121550-0009.flac
# 287  84-121550-0009  dataset/orig/84-121550-0009.flac
# 288  84-121550-0009  dataset/orig/84-121550-0009.flac
# 289  84-121550-0009  dataset/orig/84-121550-0009.flac
# 290  84-121550-0009  dataset/orig/84-121550-0009.flac
# 291  84-121550-0009  dataset/orig/84-121550-0009.flac
# 292  84-121550-0009  dataset/orig/84-121550-0009.flac
# 293  84-121550-0009  dataset/orig/84-121550-0009.flac
# 294  84-121550-0009  dataset/orig/84-121550-0009.flac
# 295  84-121550-0009  dataset/orig/84-121550-0009.flac
# 296  84-121550-0010  dataset/orig/84-121550-0010.flac
# 297  84-121550-0010  dataset/orig/84-121550-0010.flac
# 298  84-121550-0010  dataset/orig/84-121550-0010.flac
# 299  84-121550-0010  dataset/orig/84-121550-0010.flac
# 300  84-121550-0010  dataset/orig/84-121550-0010.flac
# 301  84-121550-0010  dataset/orig/84-121550-0010.flac
# 302  84-121550-0010  dataset/orig/84-121550-0010.flac
# 303  84-121550-0010  dataset/orig/84-121550-0010.flac
# 304  84-121550-0010  dataset/orig/84-121550-0010.flac
# 305  84-121550-0010  dataset/orig/84-121550-0010.flac
# 306  84-121550-0010  dataset/orig/84-121550-0010.flac
# 307  84-121550-0010  dataset/orig/84-121550-0010.flac
# 308  84-121550-0010  dataset/orig/84-121550-0010.flac
# 309  84-121550-0010  dataset/orig/84-121550-0010.flac
# 310  84-121550-0010  dataset/orig/84-121550-0010.flac
# 311  84-121550-0010  dataset/orig/84-121550-0010.flac
#
#                              name  \
# 0          84-121550-0000_train_0
# 1          84-121550-0000_train_5
# 2         84-121550-0000_train_10
# 3         84-121550-0000_train_15
# 4          84-121550-0000_train_0
# 5          84-121550-0000_train_5
# 6         84-121550-0000_train_10
# 7         84-121550-0000_train_15
# 8     84-121550-0000_restaurant_0
# 9     84-121550-0000_restaurant_5
# 10   84-121550-0000_restaurant_10
# 11   84-121550-0000_restaurant_15
# 12          84-121550-0000_hall_0
# 13          84-121550-0000_hall_5
# 14         84-121550-0000_hall_10
# 15         84-121550-0000_hall_15
# 16         84-121550-0001_train_0
# 17         84-121550-0001_train_5
# 18        84-121550-0001_train_10
# 19        84-121550-0001_train_15
# 20    84-121550-0001_restaurant_0
# 21    84-121550-0001_restaurant_5
# 22   84-121550-0001_restaurant_10
# 23   84-121550-0001_restaurant_15
# 24          84-121550-0001_hall_0
# 25          84-121550-0001_hall_5
# 26         84-121550-0001_hall_10
# 27         84-121550-0001_hall_15
# 28         84-121550-0002_train_0
# 29         84-121550-0002_train_5
# ..                            ...
# 282       84-121550-0009_train_10
# 283       84-121550-0009_train_15
# 284   84-121550-0009_restaurant_0
# 285   84-121550-0009_restaurant_5
# 286  84-121550-0009_restaurant_10
# 287  84-121550-0009_restaurant_15
# 288         84-121550-0009_hall_0
# 289         84-121550-0009_hall_5
# 290        84-121550-0009_hall_10
# 291        84-121550-0009_hall_15
# 292        84-121550-0009_white_0
# 293        84-121550-0009_white_5
# 294       84-121550-0009_white_10
# 295       84-121550-0009_white_15
# 296        84-121550-0010_train_0
# 297        84-121550-0010_train_5
# 298       84-121550-0010_train_10
# 299       84-121550-0010_train_15
# 300   84-121550-0010_restaurant_0
# 301   84-121550-0010_restaurant_5
# 302  84-121550-0010_restaurant_10
# 303  84-121550-0010_restaurant_15
# 304         84-121550-0010_hall_0
# 305         84-121550-0010_hall_5
# 306        84-121550-0010_hall_10
# 307        84-121550-0010_hall_15
# 308        84-121550-0010_white_0
# 309        84-121550-0010_white_5
# 310       84-121550-0010_white_10
# 311       84-121550-0010_white_15
#
#                                                   path  noise_type SNR talker  \
# 0    dataset/speech/84-121550-0000/train/84-121550-...       train   0     84
# 1    dataset/speech/84-121550-0000/train/84-121550-...       train   5     84
# 2    dataset/speech/84-121550-0000/train/84-121550-...       train  10     84
# 3    dataset/speech/84-121550-0000/train/84-121550-...       train  15     84
# 4    dataset/speech/84-121550-0000/train/84-121550-...       train   0     84
# 5    dataset/speech/84-121550-0000/train/84-121550-...       train   5     84
# 6    dataset/speech/84-121550-0000/train/84-121550-...       train  10     84
# 7    dataset/speech/84-121550-0000/train/84-121550-...       train  15     84
# 8    dataset/speech/84-121550-0000/restaurant/84-12...  restaurant   0     84
# 9    dataset/speech/84-121550-0000/restaurant/84-12...  restaurant   5     84
# 10   dataset/speech/84-121550-0000/restaurant/84-12...  restaurant  10     84
# 11   dataset/speech/84-121550-0000/restaurant/84-12...  restaurant  15     84
# 12   dataset/speech/84-121550-0000/hall/84-121550-0...        hall   0     84
# 13   dataset/speech/84-121550-0000/hall/84-121550-0...        hall   5     84
# 14   dataset/speech/84-121550-0000/hall/84-121550-0...        hall  10     84
# 15   dataset/speech/84-121550-0000/hall/84-121550-0...        hall  15     84
# 16   dataset/speech/84-121550-0001/train/84-121550-...       train   0     84
# 17   dataset/speech/84-121550-0001/train/84-121550-...       train   5     84
# 18   dataset/speech/84-121550-0001/train/84-121550-...       train  10     84
# 19   dataset/speech/84-121550-0001/train/84-121550-...       train  15     84
# 20   dataset/speech/84-121550-0001/restaurant/84-12...  restaurant   0     84
# 21   dataset/speech/84-121550-0001/restaurant/84-12...  restaurant   5     84
# 22   dataset/speech/84-121550-0001/restaurant/84-12...  restaurant  10     84
# 23   dataset/speech/84-121550-0001/restaurant/84-12...  restaurant  15     84
# 24   dataset/speech/84-121550-0001/hall/84-121550-0...        hall   0     84
# 25   dataset/speech/84-121550-0001/hall/84-121550-0...        hall   5     84
# 26   dataset/speech/84-121550-0001/hall/84-121550-0...        hall  10     84
# 27   dataset/speech/84-121550-0001/hall/84-121550-0...        hall  15     84
# 28   dataset/speech/84-121550-0002/train/84-121550-...       train   0     84
# 29   dataset/speech/84-121550-0002/train/84-121550-...       train   5     84
# ..                                                 ...         ...  ..    ...
# 282  dataset/speech/84-121550-0009/train/84-121550-...       train  10     84
# 283  dataset/speech/84-121550-0009/train/84-121550-...       train  15     84
# 284  dataset/speech/84-121550-0009/restaurant/84-12...  restaurant   0     84
# 285  dataset/speech/84-121550-0009/restaurant/84-12...  restaurant   5     84
# 286  dataset/speech/84-121550-0009/restaurant/84-12...  restaurant  10     84
# 287  dataset/speech/84-121550-0009/restaurant/84-12...  restaurant  15     84
# 288  dataset/speech/84-121550-0009/hall/84-121550-0...        hall   0     84
# 289  dataset/speech/84-121550-0009/hall/84-121550-0...        hall   5     84
# 290  dataset/speech/84-121550-0009/hall/84-121550-0...        hall  10     84
# 291  dataset/speech/84-121550-0009/hall/84-121550-0...        hall  15     84
# 292  dataset/speech/84-121550-0009/white/84-121550-...       white   0     84
# 293  dataset/speech/84-121550-0009/white/84-121550-...       white   5     84
# 294  dataset/speech/84-121550-0009/white/84-121550-...       white  10     84
# 295  dataset/speech/84-121550-0009/white/84-121550-...       white  15     84
# 296  dataset/speech/84-121550-0010/train/84-121550-...       train   0     84
# 297  dataset/speech/84-121550-0010/train/84-121550-...       train   5     84
# 298  dataset/speech/84-121550-0010/train/84-121550-...       train  10     84
# 299  dataset/speech/84-121550-0010/train/84-121550-...       train  15     84
# 300  dataset/speech/84-121550-0010/restaurant/84-12...  restaurant   0     84
# 301  dataset/speech/84-121550-0010/restaurant/84-12...  restaurant   5     84
# 302  dataset/speech/84-121550-0010/restaurant/84-12...  restaurant  10     84
# 303  dataset/speech/84-121550-0010/restaurant/84-12...  restaurant  15     84
# 304  dataset/speech/84-121550-0010/hall/84-121550-0...        hall   0     84
# 305  dataset/speech/84-121550-0010/hall/84-121550-0...        hall   5     84
# 306  dataset/speech/84-121550-0010/hall/84-121550-0...        hall  10     84
# 307  dataset/speech/84-121550-0010/hall/84-121550-0...        hall  15     84
# 308  dataset/speech/84-121550-0010/white/84-121550-...       white   0     84
# 309  dataset/speech/84-121550-0010/white/84-121550-...       white   5     84
# 310  dataset/speech/84-121550-0010/white/84-121550-...       white  10     84
# 311  dataset/speech/84-121550-0010/white/84-121550-...       white  15     84
#
#        book                                 orig_transcription  \
# 0    121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 1    121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 2    121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 3    121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 4    121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 5    121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 6    121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 7    121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 8    121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 9    121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 10   121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 11   121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 12   121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 13   121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 14   121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 15   121550  BUT WITH FULL RAVISHMENT THE HOURS OF PRIME SI...
# 16   121550  ALL WATERS THAT ON EARTH MOST LIMPID ARE WOULD...
# 17   121550  ALL WATERS THAT ON EARTH MOST LIMPID ARE WOULD...
# 18   121550  ALL WATERS THAT ON EARTH MOST LIMPID ARE WOULD...
# 19   121550  ALL WATERS THAT ON EARTH MOST LIMPID ARE WOULD...
# 20   121550  ALL WATERS THAT ON EARTH MOST LIMPID ARE WOULD...
# 21   121550  ALL WATERS THAT ON EARTH MOST LIMPID ARE WOULD...
# 22   121550  ALL WATERS THAT ON EARTH MOST LIMPID ARE WOULD...
# 23   121550  ALL WATERS THAT ON EARTH MOST LIMPID ARE WOULD...
# 24   121550  ALL WATERS THAT ON EARTH MOST LIMPID ARE WOULD...
# 25   121550  ALL WATERS THAT ON EARTH MOST LIMPID ARE WOULD...
# 26   121550  ALL WATERS THAT ON EARTH MOST LIMPID ARE WOULD...
# 27   121550  ALL WATERS THAT ON EARTH MOST LIMPID ARE WOULD...
# 28   121550  THOU MAKEST ME REMEMBER WHERE AND WHAT PROSERP...
# 29   121550  THOU MAKEST ME REMEMBER WHERE AND WHAT PROSERP...
# ..      ...                                                ...
# 282  121550  BETWEEN HER STEPS AND MINE WERE NOT A HUNDRED ...
# 283  121550  BETWEEN HER STEPS AND MINE WERE NOT A HUNDRED ...
# 284  121550  BETWEEN HER STEPS AND MINE WERE NOT A HUNDRED ...
# 285  121550  BETWEEN HER STEPS AND MINE WERE NOT A HUNDRED ...
# 286  121550  BETWEEN HER STEPS AND MINE WERE NOT A HUNDRED ...
# 287  121550  BETWEEN HER STEPS AND MINE WERE NOT A HUNDRED ...
# 288  121550  BETWEEN HER STEPS AND MINE WERE NOT A HUNDRED ...
# 289  121550  BETWEEN HER STEPS AND MINE WERE NOT A HUNDRED ...
# 290  121550  BETWEEN HER STEPS AND MINE WERE NOT A HUNDRED ...
# 291  121550  BETWEEN HER STEPS AND MINE WERE NOT A HUNDRED ...
# 292  121550  BETWEEN HER STEPS AND MINE WERE NOT A HUNDRED ...
# 293  121550  BETWEEN HER STEPS AND MINE WERE NOT A HUNDRED ...
# 294  121550  BETWEEN HER STEPS AND MINE WERE NOT A HUNDRED ...
# 295  121550  BETWEEN HER STEPS AND MINE WERE NOT A HUNDRED ...
# 296  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
# 297  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
# 298  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
# 299  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
# 300  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
# 301  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
# 302  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
# 303  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
# 304  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
# 305  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
# 306  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
# 307  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
# 308  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
# 309  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
# 310  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
# 311  121550  NOR EVEN THUS OUR WAY CONTINUED FAR BEFORE THE...
#
#                orig_transcription_path
# 0    dataset/trans/84-121550.trans.txt
# 1    dataset/trans/84-121550.trans.txt
# 2    dataset/trans/84-121550.trans.txt
# 3    dataset/trans/84-121550.trans.txt
# 4    dataset/trans/84-121550.trans.txt
# 5    dataset/trans/84-121550.trans.txt
# 6    dataset/trans/84-121550.trans.txt
# 7    dataset/trans/84-121550.trans.txt
# 8    dataset/trans/84-121550.trans.txt
# 9    dataset/trans/84-121550.trans.txt
# 10   dataset/trans/84-121550.trans.txt
# 11   dataset/trans/84-121550.trans.txt
# 12   dataset/trans/84-121550.trans.txt
# 13   dataset/trans/84-121550.trans.txt
# 14   dataset/trans/84-121550.trans.txt
# 15   dataset/trans/84-121550.trans.txt
# 16   dataset/trans/84-121550.trans.txt
# 17   dataset/trans/84-121550.trans.txt
# 18   dataset/trans/84-121550.trans.txt
# 19   dataset/trans/84-121550.trans.txt
# 20   dataset/trans/84-121550.trans.txt
# 21   dataset/trans/84-121550.trans.txt
# 22   dataset/trans/84-121550.trans.txt
# 23   dataset/trans/84-121550.trans.txt
# 24   dataset/trans/84-121550.trans.txt
# 25   dataset/trans/84-121550.trans.txt
# 26   dataset/trans/84-121550.trans.txt
# 27   dataset/trans/84-121550.trans.txt
# 28   dataset/trans/84-121550.trans.txt
# 29   dataset/trans/84-121550.trans.txt
# ..                                 ...
# 282  dataset/trans/84-121550.trans.txt
# 283  dataset/trans/84-121550.trans.txt
# 284  dataset/trans/84-121550.trans.txt
# 285  dataset/trans/84-121550.trans.txt
# 286  dataset/trans/84-121550.trans.txt
# 287  dataset/trans/84-121550.trans.txt
# 288  dataset/trans/84-121550.trans.txt
# 289  dataset/trans/84-121550.trans.txt
# 290  dataset/trans/84-121550.trans.txt
# 291  dataset/trans/84-121550.trans.txt
# 292  dataset/trans/84-121550.trans.txt
# 293  dataset/trans/84-121550.trans.txt
# 294  dataset/trans/84-121550.trans.txt
# 295  dataset/trans/84-121550.trans.txt
# 296  dataset/trans/84-121550.trans.txt
# 297  dataset/trans/84-121550.trans.txt
# 298  dataset/trans/84-121550.trans.txt
# 299  dataset/trans/84-121550.trans.txt
# 300  dataset/trans/84-121550.trans.txt
# 301  dataset/trans/84-121550.trans.txt
# 302  dataset/trans/84-121550.trans.txt
# 303  dataset/trans/84-121550.trans.txt
# 304  dataset/trans/84-121550.trans.txt
# 305  dataset/trans/84-121550.trans.txt
# 306  dataset/trans/84-121550.trans.txt
# 307  dataset/trans/84-121550.trans.txt
# 308  dataset/trans/84-121550.trans.txt
# 309  dataset/trans/84-121550.trans.txt
# 310  dataset/trans/84-121550.trans.txt
# 311  dataset/trans/84-121550.trans.txt
#
# [312 rows x 10 columns]
